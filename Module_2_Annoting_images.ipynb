# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaristilde/cv2/blob/main/Module_2_Annoting_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import requests

image_url = 'https://raw.githubusercontent.com/Jaristilde/cv2/main/Images/Apollo-8-Launch.jpg'
image_filename = 'Apollo-8-Launch.jpg'

response = requests.get(image_url)
if response.status_code == 200:
    with open(image_filename, 'wb') as f:
        f.write(response.content)
    print(f"Image '{image_filename}' downloaded successfully.")
else:
    print(f"Failed to download image. Status code: {response.status_code}")
# Out:
# Failed to download image. Status code: 404

# %%
# Read image as color (3 channels)
image = cv2.imread('Apollo-8-Launch.jpg', cv2.IMREAD_COLOR)

# Display the original image
plt.figure(figsize=(7, 7))
plt.imshow(image)
plt.show()

# Check image shape (height, width, channels)
print(image.shape) # Should show 3 channels
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3372264440.py in <cell line: 0>()
#       4 # Display the original image
#       5 plt.figure(figsize=(7, 7))
# ----> 6 plt.imshow(image)
#       7 plt.show()
#       8
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3590     **kwargs,
#    3591 ) -> AxesImage:
# -> 3592     __ret = gca().imshow(
#    3593         X,
#    3594         cmap=cmap,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
# ...

# %%
# Convert to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
plt.figure(figsize=(7, 7))
plt.imshow(gray_image, cmap='gray')
plt.show()

# Check image shape (height, width)
print(gray_image.shape) # Should show 2 channels
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-2746653056.py in <cell line: 0>()
#       1 # Convert to grayscale
# ----> 2 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       3
#       4 # Display the grayscale image
#       5 plt.figure(figsize=(7, 7))
#
# error: OpenCV(4.12.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
# Apply a binary threshold
# Pixels above 127 become 255 (white), below 127 become 0 (black)
ret, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)

# Display the binary image
plt.figure(figsize=(7, 7))
plt.imshow(binary_image, cmap='gray')
plt.show()

# Check image shape (height, width)
print(binary_image.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1294924685.py in <cell line: 0>()
#       1 # Apply a binary threshold
#       2 # Pixels above 127 become 255 (white), below 127 become 0 (black)
# ----> 3 ret, binary_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)
#       4
#       5 # Display the binary image
#
# NameError: name 'gray_image' is not defined
